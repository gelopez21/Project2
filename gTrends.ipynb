# %% [markdown]
# ## Google Trends

# %%
# !pip install pytrends

# %%
import pandas as pd                        
from pytrends.request import TrendReq
pytrend = TrendReq()

# %%
pytrend.build_payload(kw_list=['Vaccine'])

# Interest by Region
df = pytrend.interest_by_region()
df.reset_index()
# Out:
#             geoName  Vaccine
# 0       Afghanistan        0
# 1           Albania        0
# 2           Algeria        0
# 3    American Samoa        0
# 4           Andorra        0
# ..              ...      ...
# 245  Western Sahara        0
# 246           Yemen        0
# 247          Zambia        0
# 248        Zimbabwe        0
# 249   Åland Islands        0
#
# [250 rows x 2 columns]

# %%
df.reset_index().plot(x='geoName', y='Vaccine', figsize=(120, 10), kind ='bar')

# %%
#Google Hot Trends data
df = pytrend.trending_searches(pn='united_states')
df.head(11)
# Out:
#                      0
# 0        Hanukkah 2020
# 1         Taylor Swift
# 2     Game Awards 2020
# 3      Ellen DeGeneres
# 4            Star Wars
# 5           Susan Rice
# 6          Paul George
# 7   Hayden Christensen
# 8     Dianne Feinstein
# 9           J.J. Barea
# 10             Morocco

# %%
df = pytrend.today_searches(pn='US')

# %%
#Google Top Charts
df = pytrend.top_charts(2020, hl='en-US', tz=300, geo='GLOBAL')
df.head(10)
# Out:
#                   title exploreQuery
# 0           Coronavirus
# 1      Election results
# 2           Kobe Bryant
# 3                  Zoom
# 4                   IPL
# 5  India vs New Zealand
# 6    Coronavirus update
# 7  Coronavirus symptoms
# 8             Joe Biden
# 9      Google Classroom

# %%
#Google Keyword Suggestions
keywords = pytrend.suggestions(keyword='Mercedes Benz')
df = pd.DataFrame(keywords)

#This column makes no sense
df.drop(columns= 'mid')
# Out:
#                      title                     type
# 0            Mercedes-Benz  Luxury vehicles company
# 1    Mercedes-Benz C-Class             Mid-size car
# 2  Mercedes-Benz GLE-Class           Luxury vehicle
# 3    Mercedes-Benz S-Class           Luxury vehicle
# 4    Mercedes-Benz E-Class           Luxury vehicle

# %%
pytrend.build_payload(kw_list=['Coronavirus'])

# %%
#Related Queries, returns a dictionary of dataframes
related_queries = pytrend.related_queries()
related_queries.values()
# Out:
# dict_values([{'top':                             query  value
# 0              coronavirus update    100
# 1               coronavirus cases     88
# 2                coronavirus news     64
# 3                          corona     61
# 4                  coronavirus uk     60
# 5               india coronavirus     51
# 6            coronavirus symptoms     44
# 7   thank you coronavirus helpers     37
# 8                coronavirus tips     35
# 9                 coronavirus usa     33
# 10                coronavirus map     33
# 11                 us coronavirus     32
# 12              coronavirus world     31
# 13             france coronavirus     31
# 14             coronavirus france     31
# 15             italia coronavirus     29
# 16             coronavirus deaths     27
# 17               coronavirus live     26
# 18        coronavirus worldometer     26
# 19                   corona virus     25
# 20                    worldometer     25
# ...
